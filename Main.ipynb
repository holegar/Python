# %%
#conda install -c conda-forge imbalanced-learn

# %%
try:
    from Test import test
except ModuleNotFoundError:
    print("Please insert the module files in the program directory.")


# %matplotlib inline

# %%
test()
# Out:
# -------------------------------------------------------------------------
# [1]  Descriptive Statistics
# [2]  Exploratory Data Analysis
# [3]  Data Preparation
# [4]  Train the Model
# [0]  EXIT
# -------------------------------------------------------------------------
# Choose one of the options: 1
# -------------------------------------------------------------------------
# DESCRIPTIVE STATISTICS:
# [1]  Compute Means
# [2]  Compute Medians
# [3]  Compute Standard Deviations
# [4]  Compute Variances
# [5]  Compute Minimums
# [6]  Compute Maximums
# [7]  Compute Skewnesses
# [8]  Compute Kurtosis
# -------------------------------------------------------------------------
# Choose one of the descriptive statistics options: 5
# -------------------------------------------------------------------------
# Minimum of _id:	 1
# Minimum of orX:	 0
# Minimum of orY:	 -178
# Minimum of orZ:	 -86
# Minimum of rX:	 -0.712
# Minimum of rY:	 -0.557
# Minimum of rZ:	 -1.0
# Minimum of accX:	 -19.537
# Minimum of accY:	 -14.48
# Minimum of accZ:	 -5.976
# Minimum of gX:	 -13.658
# Minimum of gY:	 -7.986
# Minimum of gZ:	 -3.828
# Minimum of mX:	 -139.2
# Minimum of mY:	 -70.0
# Minimum of mZ:	 -107.2
# Minimum of lux:	 0
# Minimum of soundLevel:	 -26.57
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
# [1]  Descriptive Statistics
# [2]  Exploratory Data Analysis
# [3]  Data Preparation
# [4]  Train the Model
# [0]  EXIT
# -------------------------------------------------------------------------
# Choose one of the options: 1
# -------------------------------------------------------------------------
# DESCRIPTIVE STATISTICS:
# [1]  Compute Means
# [2]  Compute Medians
# [3]  Compute Standard Deviations
# [4]  Compute Variances
# [5]  Compute Minimums
# [6]  Compute Maximums
# [7]  Compute Skewnesses
# [8]  Compute Kurtosis
# -------------------------------------------------------------------------
# Choose one of the descriptive statistics options: 7
# -------------------------------------------------------------------------
# Skewness of _id:	 0.0
# Skewness of orX:	 -0.254
# Skewness of orY:	 -3.34
# Skewness of orZ:	 2.164
# Skewness of rX:	 2.293
# Skewness of rY:	 0.439
# Skewness of rZ:	 -0.163
# Skewness of accX:	 1.657
# Skewness of accY:	 0.65
# Skewness of accZ:	 -1.543
# Skewness of gX:	 2.222
# Skewness of gY:	 0.704
# Skewness of gZ:	 -3.617
# Skewness of mX:	 -0.591
# Skewness of mY:	 0.487
# Skewness of mZ:	 0.288
# Skewness of lux:	 0.622
# Skewness of soundLevel:	 -4.029
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
# [1]  Descriptive Statistics
# [2]  Exploratory Data Analysis
# [3]  Data Preparation
# [4]  Train the Model
# [0]  EXIT
# -------------------------------------------------------------------------
# Choose one of the options: q
# INVALID INPUT.
# Press Enter to continue...
# -------------------------------------------------------------------------
# [1]  Descriptive Statistics
# [2]  Exploratory Data Analysis
# [3]  Data Preparation
# [4]  Train the Model
# [0]  EXIT
# -------------------------------------------------------------------------
# Choose one of the options: 2
# -------------------------------------------------------------------------
# EXPLORATORY DATA ANALYSIS:
# [1]  Explore Data
# [2]  Variables Info
# [3]  Dataset Shape
# [4]  Number of Unique Values of Each Feature
# [5]  Number of Missing Values in Each Feature
# [6]  Class Distribution in Target Variable
# [7]  Distributions of Features
# [8]  Correlation Matrix
# [9]  Correlation Scatters
# -------------------------------------------------------------------------
# Choose one of the EDA options: 6
# -------------------------------------------------------------------------
# Frequency of Classes in Target Variable:
# Sitting               75733
# Walking               64507
# Lying                 25440
# Standing              19920
# ClimbingUpStairs       5520
# Jogging                5160
# ClimbingDownStairs     3720
# AscendingStairs        1800
# Running                1200
# Driving                 840
# MountainDescending      840
# DescendingStairs        720
# MountainAscending       120
# Name: activity, dtype: int64
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
# [1]  Descriptive Statistics
# [2]  Exploratory Data Analysis
# [3]  Data Preparation
# [4]  Train the Model
# [0]  EXIT
# -------------------------------------------------------------------------
# Choose one of the options: 2
# -------------------------------------------------------------------------
# EXPLORATORY DATA ANALYSIS:
# [1]  Explore Data
# [2]  Variables Info
# [3]  Dataset Shape
# [4]  Number of Unique Values of Each Feature
# [5]  Number of Missing Values in Each Feature
# [6]  Class Distribution in Target Variable
# [7]  Distributions of Features
# [8]  Correlation Matrix
# [9]  Correlation Scatters
# -------------------------------------------------------------------------
# Choose one of the EDA options: 8
# -------------------------------------------------------------------------
# Correlations of Features:
# (TAKES A FEW MINUTES)
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
# [1]  Descriptive Statistics
# [2]  Exploratory Data Analysis
# [3]  Data Preparation
# [4]  Train the Model
# [0]  EXIT
# -------------------------------------------------------------------------
# Choose one of the options: 3
# -------------------------------------------------------------------------
# DATA PREPARATION:
# >>>Each step applies to the output of last executed step<<<
# [1]  Deduplication
# [2]  Class Merging
# [3]  Class Balancing
# [4]  Feature Selection (ANOVA)
# [5]  Feature Extraction (PCA) (APPLIES ONLY TO BALANCED DATA)
# [6]  Split Train/Test
# [7]  Standardization (APPLIES ONLY TO SPLIT DATA)
# [8]  Normalization (APPLIES ONLY TO SPLIT DATA OR STANDARDIZED DATA)
# -------------------------------------------------------------------------
# Choose one of the data preparation options: 1
# -------------------------------------------------------------------------
#
# Shape of data before Deduplication:    (10000, 18)
#
# Shape of data after Deduplication:     (7207, 18)
#
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
# [1]  Descriptive Statistics
# [2]  Exploratory Data Analysis
# [3]  Data Preparation
# [4]  Train the Model
# [0]  EXIT
# -------------------------------------------------------------------------
# Choose one of the options: 3
# -------------------------------------------------------------------------
# DATA PREPARATION:
# >>>Each step applies to the output of last executed step<<<
# [1]  Deduplication
# [2]  Class Merging
# [3]  Class Balancing
# [4]  Feature Selection (ANOVA)
# [5]  Feature Extraction (PCA) (APPLIES ONLY TO BALANCED DATA)
# [6]  Split Train/Test
# [7]  Standardization (APPLIES ONLY TO SPLIT DATA)
# [8]  Normalization (APPLIES ONLY TO SPLIT DATA OR STANDARDIZED DATA)
# -------------------------------------------------------------------------
# Choose one of the data preparation options: 4
# -------------------------------------------------------------------------
# Enter number of features for Feature Selection:10
# Selected Features: ['orX', 'orY', 'rY', 'rZ', 'gY', 'mX', 'mY', 'mZ', 'lux', 'soundLevel']
# Selected Features: ['orX', 'orY', 'rY', 'rZ', 'gY', 'mX', 'mY', 'mZ', 'lux', 'soundLevel']
#
#
# Selected Features:
# Selected Features: ['orX', 'orY', 'rY', 'rZ', 'gY', 'mX', 'mY', 'mZ', 'lux', 'soundLevel']
# ['orX', 'orY', 'rY', 'rZ', 'gY', 'mX', 'mY', 'mZ', 'lux', 'soundLevel']
# Top 5 rows before Feature Selection:
#    orX  orY  orZ        rX        rY        rZ      accX     accY     accZ  \
# 0  125  -17    2  0.070997 -0.131696 -0.877469 -0.038307  2.68151  8.65743
# 1  126  -17    2  0.071486 -0.131480 -0.878024 -0.038307  2.68151  8.65743
# 2  127  -17    2  0.071401 -0.131551 -0.878799  0.153229  2.68151  8.65743
# 3  127  -17    2  0.071401 -0.131551 -0.878799  0.153229  2.68151  8.65743
# 4  127  -17    2  0.070772 -0.131888 -0.879645  0.153229  2.68151  8.65743
#
#          gX       gY       gZ    mX    mY    mZ   lux  soundLevel  activity
# 0 -0.041316  2.67655  8.64271 -31.2 -35.6 -37.6  5000       49.56        10
# 1 -0.054196  2.67834  8.64654 -31.2 -36.0 -37.2  5000       53.38        10
# 2 -0.056867  2.68004  8.65088 -31.2 -36.0 -37.2  5000       53.38        10
# 3 -0.056867  2.68004  8.65088 -31.2 -36.0 -37.2  5000       49.53        10
# 4 -0.049128  2.68130  8.65458 -31.2 -35.6 -36.8  5000       49.53        10
# Top 5 rows after Feature Selection:
#    orX  orY        rY        rZ       gY    mX    mY    mZ   lux  soundLevel  \
# 0  125  -17 -0.131696 -0.877469  2.67655 -31.2 -35.6 -37.6  5000       49.56
# 1  126  -17 -0.131480 -0.878024  2.67834 -31.2 -36.0 -37.2  5000       53.38
# 2  127  -17 -0.131551 -0.878799  2.68004 -31.2 -36.0 -37.2  5000       53.38
# 3  127  -17 -0.131551 -0.878799  2.68004 -31.2 -36.0 -37.2  5000       49.53
# 4  127  -17 -0.131888 -0.879645  2.68130 -31.2 -35.6 -36.8  5000       49.53
#
#    activity
# 0        10
# 1        10
# 2        10
# 3        10
# 4        10
# Shape of data before Feature Selection:    (7207, 18)
# Shape of data after Feature Selection:     (7207, 11)
#
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
# [1]  Descriptive Statistics
# [2]  Exploratory Data Analysis
# [3]  Data Preparation
# [4]  Train the Model
# [0]  EXIT
# -------------------------------------------------------------------------
# Choose one of the options: 3
# -------------------------------------------------------------------------
# DATA PREPARATION:
# >>>Each step applies to the output of last executed step<<<
# [1]  Deduplication
# [2]  Class Merging
# [3]  Class Balancing
# [4]  Feature Selection (ANOVA)
# [5]  Feature Extraction (PCA) (APPLIES ONLY TO BALANCED DATA)
# [6]  Split Train/Test
# [7]  Standardization (APPLIES ONLY TO SPLIT DATA)
# [8]  Normalization (APPLIES ONLY TO SPLIT DATA OR STANDARDIZED DATA)
# -------------------------------------------------------------------------
# Choose one of the data preparation options: 6
# -------------------------------------------------------------------------
# Enter percent of test data (0-100):30
#
#
# Shape of data before Split:
#                 (7207, 11)
#
# Shape of data after Split:
#     X Train:    (5044, 10)
#     X Test:     (2163, 10)
#     Y Train:    (5044,)
#     Y Test:     (2163,)
#
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
# [1]  Descriptive Statistics
# [2]  Exploratory Data Analysis
# [3]  Data Preparation
# [4]  Train the Model
# [0]  EXIT
# -------------------------------------------------------------------------
# Choose one of the options: 3
# -------------------------------------------------------------------------
# DATA PREPARATION:
# >>>Each step applies to the output of last executed step<<<
# [1]  Deduplication
# [2]  Class Merging
# [3]  Class Balancing
# [4]  Feature Selection (ANOVA)
# [5]  Feature Extraction (PCA) (APPLIES ONLY TO BALANCED DATA)
# [6]  Split Train/Test
# [7]  Standardization (APPLIES ONLY TO SPLIT DATA)
# [8]  Normalization (APPLIES ONLY TO SPLIT DATA OR STANDARDIZED DATA)
# -------------------------------------------------------------------------
# Choose one of the data preparation options: 7
# -------------------------------------------------------------------------
#
#
# Top 5 rows of features before Standardization:
#       orX  orY        rY        rZ        gY    mX    mY    mZ   lux  \
# 5859   43    7 -0.083194 -0.314836 -0.821631 -23.6  23.6 -50.0  5000
# 4784  209   33 -0.111569  0.889989 -1.898720  23.6 -15.2 -45.2  5000
# 5057  247   24 -0.074683  0.814287 -2.467590  22.0   3.2 -43.6  5000
# 6691  249    7 -0.042238  0.820434 -1.416550  20.8   1.2 -53.2  5000
# 2348  152   16  0.053020 -0.989067 -1.191630 -18.8 -28.8 -34.8     5
#
#       soundLevel
# 5859       54.64
# 4784       55.43
# 5057       56.86
# 6691       59.17
# 2348       57.66
# Top 5 rows of features after Standardization:
#           0         1         2         3         4         5         6  \
# 0 -1.864718  0.095346 -1.071691 -0.553687  0.293781 -0.991787  2.066872
# 1  0.518470  3.064721 -1.493076  0.903200 -0.654631  0.980336 -0.294095
# 2  1.064018  2.036861 -0.945313  0.811661 -1.155539  0.913484  0.825538
# 3  1.092732  0.095346 -0.463495  0.819094 -0.230064  0.863345  0.703839
# 4 -0.299854  1.123207  0.951127 -1.368974 -0.032015 -0.791232 -1.121651
#
#           7         8         9
# 0 -1.083984  0.674978 -0.278924
# 1 -0.672132  0.674978 -0.106736
# 2 -0.534847  0.674978  0.204948
# 3 -1.358552  0.674978  0.708436
# 4  0.220215 -1.753768  0.379316
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
# [1]  Descriptive Statistics
# [2]  Exploratory Data Analysis
# [3]  Data Preparation
# [4]  Train the Model
# [0]  EXIT
# -------------------------------------------------------------------------
# Choose one of the options: 4
# -------------------------------------------------------------------------
# TRAIN THE MODEL:
# [1]  Random Forest
# [2]  Support Vector Machine
# [3]  Multi Layer Perceptron
# [4]  K-Nearest Neighbours
# -------------------------------------------------------------------------
# Choose one of the train options: 4
# -------------------------------------------------------------------------
# K-NEAREST NEIGHBOURS:
# Enter number of neighbours:3
#
# Please wait for the model to be trained...
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.97      0.98      0.98       273
#            2       0.98      0.97      0.97       213
#            5       0.90      0.86      0.88       159
#           10       1.00      1.00      1.00       146
#           11       0.99      0.99      0.99       515
#           12       0.97      0.98      0.97       857
#
#     accuracy                           0.97      2163
#    macro avg       0.97      0.96      0.97      2163
# weighted avg       0.97      0.97      0.97      2163
#
#
# Train set accuracy: 99.09 %
# Test set accuracy: 97.32 %
#
# KNN training time: 1.0 seconds
# -------------------------------------------------------------------------
# -------------------------------------------------------------------------
# [1]  Descriptive Statistics
# [2]  Exploratory Data Analysis
# [3]  Data Preparation
# [4]  Train the Model
# [0]  EXIT
# -------------------------------------------------------------------------
# Choose one of the options: 0
# GOODBYE.
